# %%
import turtle

turtle.bgcolor('lavender')
turtle.colormode(255)
tl= turtle.Turtle()
tl.hideturtle()

tl.penup()
tl.forward(250)
tl.left(90)
tl.forward(200)
tl.pendown()

# Vẽ mặt trời
tl.pencolor('yellow')
tl.fillcolor('yellow')
tl.begin_fill()
tl.circle(50)
tl.end_fill()

tl.pensize(4)
tl.right(90)
tl.forward(50)
tl.backward(200)
tl.forward(100)
tl.left(90)
tl.forward(100)
tl.backward(200)
tl.forward(100)
tl.pensize(2)
tl.left(45)
tl.forward(75)
tl.backward(150)
tl.forward(75)
tl.right(90)
tl.forward(75)
tl.backward(150)

##############
tl.penup()
tl.right(135)
tl.forward(350)
tl.left(90)
tl.pendown()

# Vẽ cây

tl.pencolor('brown')
tl.fillcolor('brown')
tl.penup()
tl.forward(62.5)
tl.right(90)
tl.pendown()
tl.begin_fill()
tl.forward(75)
tl.left(90)
tl.forward(25)
tl.left(90)
tl.forward(75)
tl.end_fill()
tl.penup()
tl.left(90)
tl.forward(87.5)
tl.left(180)
tl.pendown()

tl.pencolor('green')
tl.fillcolor('green')
tl.begin_fill()
tl.forward(150)
tl.left(135)
tl.forward(105)
tl.left(90)
tl.forward(105)
tl.end_fill()

tl.backward(105)
tl.left(135)
tl.forward(65)

tl.begin_fill()
tl.backward(130)
tl.left(45)
tl.forward(91)
tl.right(90)
tl.forward(91)
tl.end_fill()

tl.backward(91)
tl.left(45)
tl.forward(55)

tl.begin_fill()
tl.backward(110)
tl.left(45)
tl.forward(77)
tl.right(90)
tl.forward(77)
tl.end_fill()

#Vẽ nhà 

tl.penup()
tl.right(135)
tl.forward(400)
tl.left(90)
tl.backward(75)
tl.pendown()
tl.pencolor(0,204,204)
tl.fillcolor((0,204,204))
tl.begin_fill()
tl.forward(200)
tl.left(100)
tl.forward(150)
tl.left(80)
tl.forward(200)
tl.left(100)
tl.forward(150)
tl.end_fill()

tl.penup()
tl.backward(55)
tl.left(80)
tl.forward(40)
tl.pendown()

tl.pencolor(255,204,153)
tl.fillcolor(255,204,153)
tl.begin_fill()
tl.forward(50)
tl.left(100)
tl.forward(40)
tl.left(80)
tl.forward(50)
tl.left(100)
tl.forward(40)
tl.end_fill()

tl.penup()
tl.right(100)
tl.forward(40)
tl.left(100)
tl.forward(55)
tl.right(10)
tl.pendown()

tl.pencolor(0,102,102)
tl.fillcolor(0,102,102)
tl.begin_fill()
tl.forward(200)
tl.left(90)
tl.forward(200)
tl.left(90)
tl.forward(200)
tl.left(90)
tl.forward(200)
tl.left(90)
tl.forward(200)
tl.end_fill()

tl.penup()
tl.backward(62.5)
tl.left(90)
tl.forward(200)
tl.pendown()

tl.pencolor(255,204,153)
tl.fillcolor(255,204,153)
tl.begin_fill()
tl.backward(120)
tl.left(90)
tl.forward(75)
tl.right(90)
tl.forward(120)
tl.end_fill()

tl.penup()
tl.backward(200)
tl.left(90)
tl.forward(62.5)
tl.left(135)
tl.pendown()

tl.pencolor(204,0,0)
tl.fillcolor(204,0,0)
tl.begin_fill()
tl.forward(141.42)
tl.left(90)
tl.forward(141.42)
tl.end_fill()

tl.penup()
tl.backward(141.42)
tl.left(145)
tl.pendown()

tl.pencolor(255,51,51)
tl.fillcolor(255,51,51)
tl.begin_fill()
tl.forward(150)
tl.right(55)
tl.forward(141.42)
tl.right(125)
tl.forward(150)
tl.end_fill()


turtle.done()
