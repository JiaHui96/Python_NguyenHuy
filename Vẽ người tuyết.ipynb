# %%
import turtle

turtle.colormode(255)
turtle.bgcolor(153,209,211)
tl= turtle.Turtle()
tl.speed(5)
tl.pensize(2)
tl.pencolor('white')

#tl.hideturtle()
#Thân to
tl.penup()
tl.goto(0,-160)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(100)
tl.end_fill()
#Đầu
tl.penup()
tl.goto(0,40)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(60)
tl.end_fill()
#Hai mắt
tl.penup()
tl.goto(20,110)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(10)
tl.end_fill()
tl.penup()
tl.goto(-20,110)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(10)
tl.end_fill()
#Mắt nhỏ
tl.penup()
tl.goto(22,118)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(3)
tl.end_fill()
tl.penup()
tl.goto(-18,118)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(3)
tl.end_fill()
#Ba khuy áo
tl.penup()
tl.goto(0,10)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(7)
tl.end_fill()
tl.penup()
tl.goto(0,10-14-10)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(7)
tl.end_fill()
tl.penup()
tl.goto(0,10-14*2-10*2)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(7)
tl.end_fill()
#Mũ

tl.penup()
tl.goto(-45,150)
tl.pendown()
tl.fillcolor('grey')
tl.begin_fill()
tl.goto(-25,200)
tl.forward(50)
tl.goto(45,150)
tl.backward(90)
tl.end_fill()
#Hai tay
tl.pensize(5)
tl.penup()
tl.goto(70,-10)
tl.pendown()
tl.goto(100,60)
tl.penup()
tl.goto(-70,-10)
tl.pendown()
tl.goto(-100,60)
tl.pensize(2)
tl.penup()
tl.goto(70+150/7,40)
tl.pendown()
tl.goto(85,70)
tl.penup()
tl.goto(70+90/7,20)
tl.pendown()
tl.goto(105,35)
tl.penup()
tl.goto(-70-150/7,40)
tl.pendown()
tl.goto(-85,70)
tl.penup()
tl.goto(-70-90/7,20)
tl.pendown()
tl.goto(-105,35)
#Mũi
tl.penup()
tl.goto(-10,100)
tl.pendown()
tl.fillcolor('orange')
tl.begin_fill()
tl.forward(20)
tl.right(30)
tl.forward(25)
tl.goto(-10,100)
tl.end_fill()
#tl.circle(10)
#Miệng
tl.pencolor('red')
tl.penup()
tl.left(30)
tl.goto(-5,60)
tl.pendown()
tl.circle(10,90)
tl.left(180)
tl.circle(10,90)
#Khăn
tl.penup()
tl.goto(-50,40)
tl.pendown()
tl.pensize(25)
tl.pencolor('green')
tl.forward(100)
tl.right(90)
tl.pensize(15)
tl.forward(40)
tl.penup()
tl.goto(25,40)
tl.pendown()
tl.forward(30)
tl.penup()
tl.goto(-40,47)
tl.pendown()
tl.pensize(10)
tl.pencolor('red')
tl.forward(15)
tl.penup()
tl.goto(-10,47)
tl.pendown()
tl.forward(15)
tl.penup()
tl.goto(20,47)
tl.pendown()
tl.forward(15)
tl.penup()
tl.goto(50,47)
tl.pendown()
tl.forward(15)

#Tuyết
tl.speed(20)
tl.pensize(20)
tl.pencolor('white')
tl.penup()
tl.goto(-250,250)
tl.pendown()
tl.circle(10)
tl.penup()
tl.goto(200,220)
tl.pendown()
tl.circle(10)
tl.penup()
tl.goto(-280,100)
tl.pendown()
tl.circle(10)
tl.penup()
tl.goto(150,80)
tl.pendown()
tl.circle(10)
tl.penup()
tl.goto(300,0)
tl.pendown()
tl.circle(10)
tl.pensize(10)
tl.penup()
tl.goto(-200,280)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(-180,100)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(-300,0)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(50,250)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(-50,220)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(280,200)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(150,-50)
tl.pendown()
tl.circle(5)
tl.penup()
tl.goto(200,-100)
tl.pendown()
tl.circle(5)

#Mặt đất
tl.penup()
tl.goto(-300,-300)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(150)
tl.end_fill()
tl.penup()
tl.goto(-600,-280)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(200)
tl.end_fill()
tl.penup()
tl.goto(-100,-500)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(300)
tl.end_fill()

turtle.done()
